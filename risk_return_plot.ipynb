# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
results_df = pd.read_csv('returns_and_risk_summary.csv')

# %%
results_df.columns
# Out:
# Index(['Ticker', 'Mean Return (Annualized)', 'Risk (Annualized Std Dev)'], dtype='object')

# %%
fig = plt.figure(figsize=(20, 16))

ax = fig.add_subplot(1, 1, 1)

ax.scatter(results_df['Risk (Annualized Std Dev)'], results_df['Mean Return (Annualized)'], s=0.5)
