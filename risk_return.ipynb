# %%
import pandas as pd
import yfinance as yf

# %%
def get_stock_data(ticker, start_date, end_date):
    """
    指定されたティッカー、開始年月日、終了年月日に基づいて株価データを取得する関数。
    
    Parameters:
    ticker (str): 取得する株のティッカーシンボル。
    start_date (str): 取得するデータの開始年月日（形式: 'YYYY-MM-DD'）。
    end_date (str): 取得するデータの終了年月日（形式: 'YYYY-MM-DD'）。
    
    Returns:
    pd.DataFrame: 取得した株価データを含むデータフレーム。
    """
    # yfinanceを使用してデータを取得
    stock = yf.Ticker(ticker)
    stock_data = stock.history(start=start_date, end=end_date)
    
    return stock_data

# %%
def calculate_returns_and_risk(stock_data):
    """
    株価データからリターンとリスク（標準偏差）を計算する関数。
    
    Parameters:
    stock_data (pd.DataFrame): 株価データを含むデータフレーム。
    
    Returns:
    tuple: 日次リターンの平均（年率換算）とリスク（標準偏差の年率換算）。
    """
    # 日次リターンを計算（パーセントリターン）
    stock_data['Return'] = stock_data['Close'].pct_change()

    # 年率リターンとリスクを計算
    mean_return = stock_data['Return'].mean() * 252  # 年率リターン
    risk = stock_data['Return'].std() * (252 ** 0.5)  # 年率リスク（標準偏差）
    
    return mean_return, risk

# %%
# ティッカーシンボルのCSVファイルを読み込み
ticker_df = pd.read_csv('company_nyse.csv')  # CSVファイルの名前を指定

# 開始日と終了日を指定
start_date = "2023-01-01"
end_date = "2023-12-31"

# 各ティッカーのリターンとリスクを格納するリスト
results = []

# ティッカーシンボルごとに株価データを取得し、リターンとリスクを計算
for ticker in ticker_df['Symbol']:
    try:
        print(f"Processing {ticker}...")
        stock_data = get_stock_data(ticker, start_date, end_date)
        
        # データが存在しない場合はスキップ
        if stock_data.empty:
            print(f"No data for {ticker}")
            continue
        
        # リターンとリスクを計算
        mean_return, risk = calculate_returns_and_risk(stock_data)
        
        # 結果をリストに追加
        results.append({'Ticker': ticker, 'Mean Return (Annualized)': mean_return, 'Risk (Annualized Std Dev)': risk})
    
    except Exception as e:
        print(f"Error processing {ticker}: {e}")

# リターンとリスクを含むデータフレームを作成
results_df = pd.DataFrame(results)

# 計算結果を表示
print(results_df)

# 計算結果をCSVファイルに保存する場合
results_df.to_csv('returns_and_risk_summary.csv', index=False)
# Out:
# Processing A...
# Processing AA...
# Processing AACT...
# Processing AACT.U...
# Got error from yahoo api for ticker AACT.U, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AACT.U: No data found for this date range, symbol may be delisted
# No data for AACT.U
# Processing AACT.W...
# Got error from yahoo api for ticker AACT.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AACT.W: No data found for this date range, symbol may be delisted
# No data for AACT.W
# Processing AAM.U...
# Got error from yahoo api for ticker AAM.U, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AAM.U: No data found for this date range, symbol may be delisted
# No data for AAM.U
# Processing AAN...
# Processing AAP...
# Processing AAT...
# Processing AB...
# Processing ABBV...
# Processing ABCB...
# Processing ABEV...
# Processing ABG...
# Processing ABM...
# Processing ABR...
# Processing ABR$D...
# Got error from yahoo api for ticker ABR$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ABR$D: No data found for this date range, symbol may be delisted
# No data for ABR$D
# Processing ABR$E...
# Got error from yahoo api for ticker ABR$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ABR$E: No data found for this date range, symbol may be delisted
# No data for ABR$E
# Processing ABR$F...
# Got error from yahoo api for ticker ABR$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ABR$F: No data found for this date range, symbol may be delisted
# No data for ABR$F
# Processing ABT...
# Processing AC...
# Processing ACA...
# Processing ACCO...
# Processing ACEL...
# Processing ACHR...
# Processing ACHR.W...
# Got error from yahoo api for ticker ACHR.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ACHR.W: No data found for this date range, symbol may be delisted
# No data for ACHR.W
# Processing ACI...
# Processing ACM...
# Processing ACN...
# Processing ACP...
# Processing ACP$A...
# Got error from yahoo api for ticker ACP$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ACP$A: No data found for this date range, symbol may be delisted
# No data for ACP$A
# Processing ACR...
# Processing ACR$C...
# Got error from yahoo api for ticker ACR$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ACR$C: No data found for this date range, symbol may be delisted
# No data for ACR$C
# Processing ACR$D...
# Got error from yahoo api for ticker ACR$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ACR$D: No data found for this date range, symbol may be delisted
# No data for ACR$D
# Processing ACRE...
# Processing ACV...
# Processing ADC...
# Processing ADC$A...
# Got error from yahoo api for ticker ADC$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ADC$A: No data found for this date range, symbol may be delisted
# No data for ADC$A
# Processing ADCT...
# Processing ADM...
# Processing ADNT...
# Processing ADT...
# Processing ADX...
# Processing AEE...
# Processing AEFC...
# Processing AEG...
# Processing AEM...
# Processing AEO...
# Processing AER...
# Processing AES...
# Processing AESI...
# Processing AEVA...
# Processing AEVA.W...
# Got error from yahoo api for ticker AEVA.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AEVA.W: No data found for this date range, symbol may be delisted
# No data for AEVA.W
# Processing AFB...
# Processing AFG...
# Processing AFGB...
# Processing AFGC...
# Processing AFGD...
# Processing AFGE...
# Processing AFL...
# Processing AG...
# Processing AGCO...
# Processing AGD...
# Processing AGI...
# Processing AGL...
# Processing AGM...
# Processing AGM$D...
# Got error from yahoo api for ticker AGM$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AGM$D: No data found for this date range, symbol may be delisted
# No data for AGM$D
# Processing AGM$E...
# Got error from yahoo api for ticker AGM$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AGM$E: No data found for this date range, symbol may be delisted
# No data for AGM$E
# Processing AGM$F...
# Got error from yahoo api for ticker AGM$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AGM$F: No data found for this date range, symbol may be delisted
# No data for AGM$F
# Processing AGM$G...
# Got error from yahoo api for ticker AGM$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AGM$G: No data found for this date range, symbol may be delisted
# No data for AGM$G
# Processing AGM.A...
# Got error from yahoo api for ticker AGM.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AGM.A: No data found for this date range, symbol may be delisted
# No data for AGM.A
# Processing AGO...
# Processing AGR...
# Processing AGRO...
# Processing AGS...
# Processing AGX...
# Processing AHH...
# Processing AHH$A...
# Got error from yahoo api for ticker AHH$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHH$A: No data found for this date range, symbol may be delisted
# No data for AHH$A
# Processing AHL$C...
# Got error from yahoo api for ticker AHL$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHL$C: No data found for this date range, symbol may be delisted
# No data for AHL$C
# Processing AHL$D...
# Got error from yahoo api for ticker AHL$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHL$D: No data found for this date range, symbol may be delisted
# No data for AHL$D
# Processing AHL$E...
# Got error from yahoo api for ticker AHL$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHL$E: No data found for this date range, symbol may be delisted
# No data for AHL$E
# Processing AHR...
# - AHR: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for AHR
# Processing AHT...
# Processing AHT$D...
# Got error from yahoo api for ticker AHT$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHT$D: No data found for this date range, symbol may be delisted
# No data for AHT$D
# Processing AHT$F...
# Got error from yahoo api for ticker AHT$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHT$F: No data found for this date range, symbol may be delisted
# No data for AHT$F
# Processing AHT$G...
# Got error from yahoo api for ticker AHT$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHT$G: No data found for this date range, symbol may be delisted
# No data for AHT$G
# Processing AHT$H...
# Got error from yahoo api for ticker AHT$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHT$H: No data found for this date range, symbol may be delisted
# No data for AHT$H
# Processing AHT$I...
# Got error from yahoo api for ticker AHT$I, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AHT$I: No data found for this date range, symbol may be delisted
# No data for AHT$I
# Processing AI...
# Processing AIFD...
# - AIFD: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for AIFD
# Processing AIG...
# Processing AIN...
# Processing AIO...
# Processing AIR...
# Processing AIT...
# Processing AIU...
# Processing AIV...
# Processing AIZ...
# Processing AIZN...
# Processing AJG...
# Processing AJX...
# Processing AKA...
# Processing AKO.A...
# Got error from yahoo api for ticker AKO.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AKO.A: No data found for this date range, symbol may be delisted
# No data for AKO.A
# Processing AKO.B...
# Got error from yahoo api for ticker AKO.B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AKO.B: No data found for this date range, symbol may be delisted
# No data for AKO.B
# Processing AKR...
# Processing AL...
# Processing AL$A...
# Got error from yahoo api for ticker AL$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AL$A: No data found for this date range, symbol may be delisted
# No data for AL$A
# Processing ALB...
# Processing ALB$A...
# Got error from yahoo api for ticker ALB$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALB$A: No data found for this date range, symbol may be delisted
# No data for ALB$A
# Processing ALC...
# Processing ALE...
# Processing ALEX...
# Processing ALG...
# Processing ALIT...
# Processing ALK...
# Processing ALL...
# Processing ALL$B...
# Got error from yahoo api for ticker ALL$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALL$B: No data found for this date range, symbol may be delisted
# No data for ALL$B
# Processing ALL$H...
# Got error from yahoo api for ticker ALL$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALL$H: No data found for this date range, symbol may be delisted
# No data for ALL$H
# Processing ALL$I...
# Got error from yahoo api for ticker ALL$I, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALL$I: No data found for this date range, symbol may be delisted
# No data for ALL$I
# Processing ALL$J...
# Got error from yahoo api for ticker ALL$J, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALL$J: No data found for this date range, symbol may be delisted
# No data for ALL$J
# Processing ALLE...
# Processing ALLG...
# Processing ALLY...
# Processing ALSN...
# Processing ALTG...
# Processing ALTG$A...
# Got error from yahoo api for ticker ALTG$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALTG$A: No data found for this date range, symbol may be delisted
# No data for ALTG$A
# Processing ALTM...
# Processing ALUR...
# Processing ALUR.W...
# Got error from yahoo api for ticker ALUR.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ALUR.W: No data found for this date range, symbol may be delisted
# No data for ALUR.W
# Processing ALV...
# Processing ALX...
# Processing AM...
# Processing AMBC...
# Processing AMBP...
# Processing AMBP.W...
# Got error from yahoo api for ticker AMBP.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AMBP.W: No data found for this date range, symbol may be delisted
# No data for AMBP.W
# Processing AMC...
# Processing AMCR...
# Processing AME...
# Processing AMG...
# Processing AMH...
# Processing AMH$G...
# Got error from yahoo api for ticker AMH$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AMH$G: No data found for this date range, symbol may be delisted
# No data for AMH$G
# Processing AMH$H...
# Got error from yahoo api for ticker AMH$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AMH$H: No data found for this date range, symbol may be delisted
# No data for AMH$H
# Processing AMK...
# Processing AMN...
# Processing AMP...
# Processing AMPS...
# Processing AMPX...
# Processing AMPX.W...
# Got error from yahoo api for ticker AMPX.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AMPX.W: No data found for this date range, symbol may be delisted
# No data for AMPX.W
# Processing AMPY...
# Processing AMR...
# Processing AMRC...
# Processing AMT...
# Processing AMTB...
# Processing AMTD...
# Processing AMWL...
# Processing AMX...
# Processing AN...
# Processing ANET...
# Processing ANF...
# Processing ANG$A...
# Got error from yahoo api for ticker ANG$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ANG$A: No data found for this date range, symbol may be delisted
# No data for ANG$A
# Processing ANG$B...
# Got error from yahoo api for ticker ANG$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ANG$B: No data found for this date range, symbol may be delisted
# No data for ANG$B
# Processing ANRO...
# - ANRO: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for ANRO
# Processing ANVS...
# Processing AOD...
# Processing AOMN...
# - AOMN: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for AOMN
# Processing AOMR...
# Processing AON...
# Processing AORT...
# Processing AOS...
# Processing AP...
# Processing APAM...
# Processing APD...
# Processing APG...
# Processing APH...
# Processing APLE...
# Processing APO...
# Processing APO$A...
# Got error from yahoo api for ticker APO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - APO$A: No data found for this date range, symbol may be delisted
# No data for APO$A
# Processing APOS...
# Processing APTV...
# Processing AQN...
# Processing AQNB...
# Processing AR...
# Processing ARC...
# Processing ARCH...
# Processing ARCO...
# Processing ARDC...
# Processing ARDT...
# - ARDT: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for ARDT
# Processing ARE...
# Processing ARES...
# Processing ARGD...
# Processing ARGO$A...
# Got error from yahoo api for ticker ARGO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ARGO$A: No data found for this date range, symbol may be delisted
# No data for ARGO$A
# Processing ARI...
# Processing ARIS...
# Processing ARL...
# Processing ARLO...
# Processing ARMK...
# Processing AROC...
# Processing ARR...
# Processing ARR$C...
# Got error from yahoo api for ticker ARR$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ARR$C: No data found for this date range, symbol may be delisted
# No data for ARR$C
# Processing ARW...
# Processing AS...
# - AS: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for AS
# Processing ASA...
# Processing ASAI...
# Processing ASAN...
# Processing ASB...
# Processing ASB$E...
# Got error from yahoo api for ticker ASB$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ASB$E: No data found for this date range, symbol may be delisted
# No data for ASB$E
# Processing ASB$F...
# Got error from yahoo api for ticker ASB$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ASB$F: No data found for this date range, symbol may be delisted
# No data for ASB$F
# Processing ASBA...
# Processing ASC...
# Processing ASG...
# Processing ASGI...
# Processing ASGN...
# Processing ASH...
# Processing ASIX...
# Processing ASPN...
# Processing ASR...
# Processing ASX...
# Processing ATCO$D...
# Got error from yahoo api for ticker ATCO$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATCO$D: No data found for this date range, symbol may be delisted
# No data for ATCO$D
# Processing ATCO$H...
# Got error from yahoo api for ticker ATCO$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATCO$H: No data found for this date range, symbol may be delisted
# No data for ATCO$H
# Processing ATEN...
# Processing ATGE...
# Processing ATH$A...
# Got error from yahoo api for ticker ATH$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATH$A: No data found for this date range, symbol may be delisted
# No data for ATH$A
# Processing ATH$B...
# Got error from yahoo api for ticker ATH$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATH$B: No data found for this date range, symbol may be delisted
# No data for ATH$B
# Processing ATH$C...
# Got error from yahoo api for ticker ATH$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATH$C: No data found for this date range, symbol may be delisted
# No data for ATH$C
# Processing ATH$D...
# Got error from yahoo api for ticker ATH$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATH$D: No data found for this date range, symbol may be delisted
# No data for ATH$D
# Processing ATH$E...
# Got error from yahoo api for ticker ATH$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - ATH$E: No data found for this date range, symbol may be delisted
# No data for ATH$E
# Processing ATHM...
# Processing ATHS...
# - ATHS: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for ATHS
# Processing ATI...
# Processing ATIP...
# Processing ATKR...
# Processing ATMU...
# Processing ATO...
# Processing ATR...
# Processing ATS...
# Processing ATUS...
# Processing AU...
# Processing AUB...
# Processing AUB$A...
# Got error from yahoo api for ticker AUB$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AUB$A: No data found for this date range, symbol may be delisted
# No data for AUB$A
# Processing AUNA...
# - AUNA: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for AUNA
# Processing AVA...
# Processing AVAL...
# Processing AVB...
# Processing AVD...
# Processing AVK...
# Processing AVNS...
# Processing AVNT...
# Processing AVTR...
# Processing AVY...
# Processing AWF...
# Processing AWI...
# Processing AWK...
# Processing AWP...
# Processing AWR...
# Processing AX...
# Processing AXL...
# Processing AXP...
# Processing AXR...
# Processing AXS...
# Processing AXS$E...
# Got error from yahoo api for ticker AXS$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - AXS$E: No data found for this date range, symbol may be delisted
# No data for AXS$E
# Processing AXTA...
# Processing AYI...
# Processing AZEK...
# Processing AZO...
# Processing AZUL...
# Processing AZZ...
# Processing B...
# Processing BA...
# Processing BABA...
# Processing BAC...
# Processing BAC$B...
# Got error from yahoo api for ticker BAC$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$B: No data found for this date range, symbol may be delisted
# No data for BAC$B
# Processing BAC$E...
# Got error from yahoo api for ticker BAC$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$E: No data found for this date range, symbol may be delisted
# No data for BAC$E
# Processing BAC$K...
# Got error from yahoo api for ticker BAC$K, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$K: No data found for this date range, symbol may be delisted
# No data for BAC$K
# Processing BAC$L...
# Got error from yahoo api for ticker BAC$L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$L: No data found for this date range, symbol may be delisted
# No data for BAC$L
# Processing BAC$M...
# Got error from yahoo api for ticker BAC$M, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$M: No data found for this date range, symbol may be delisted
# No data for BAC$M
# Processing BAC$N...
# Got error from yahoo api for ticker BAC$N, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$N: No data found for this date range, symbol may be delisted
# No data for BAC$N
# Processing BAC$O...
# Got error from yahoo api for ticker BAC$O, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$O: No data found for this date range, symbol may be delisted
# No data for BAC$O
# Processing BAC$P...
# Got error from yahoo api for ticker BAC$P, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$P: No data found for this date range, symbol may be delisted
# No data for BAC$P
# Processing BAC$Q...
# Got error from yahoo api for ticker BAC$Q, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$Q: No data found for this date range, symbol may be delisted
# No data for BAC$Q
# Processing BAC$S...
# Got error from yahoo api for ticker BAC$S, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BAC$S: No data found for this date range, symbol may be delisted
# No data for BAC$S
# Processing BAH...
# Processing BAK...
# Processing BALL...
# Processing BALY...
# Processing BAM...
# Processing BANC...
# Processing BANC$F...
# Got error from yahoo api for ticker BANC$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BANC$F: No data found for this date range, symbol may be delisted
# No data for BANC$F
# Processing BAP...
# Processing BARK...
# Processing BARK.W...
# Got error from yahoo api for ticker BARK.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BARK.W: No data found for this date range, symbol may be delisted
# No data for BARK.W
# Processing BAX...
# Processing BB...
# Processing BBAI...
# Processing BBAI.W...
# Got error from yahoo api for ticker BBAI.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BBAI.W: No data found for this date range, symbol may be delisted
# No data for BBAI.W
# Processing BBAR...
# Processing BBD...
# Processing BBDC...
# Processing BBDO...
# Processing BBN...
# Processing BBU...
# Processing BBUC...
# Processing BBVA...
# Processing BBW...
# Processing BBWI...
# Processing BBY...
# Processing BC...
# Processing BC$A...
# Got error from yahoo api for ticker BC$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BC$A: No data found for this date range, symbol may be delisted
# No data for BC$A
# Processing BC$B...
# Got error from yahoo api for ticker BC$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BC$B: No data found for this date range, symbol may be delisted
# No data for BC$B
# Processing BC$C...
# Got error from yahoo api for ticker BC$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BC$C: No data found for this date range, symbol may be delisted
# No data for BC$C
# Processing BCAT...
# Processing BCC...
# Processing BCE...
# Processing BCH...
# Processing BCO...
# Processing BCS...
# Processing BCSF...
# Processing BCX...
# Processing BDC...
# Processing BDJ...
# Processing BDN...
# Processing BDX...
# Processing BE...
# Processing BEDU...
# Processing BEKE...
# Processing BEN...
# Processing BEP...
# Processing BEP$A...
# Got error from yahoo api for ticker BEP$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BEP$A: No data found for this date range, symbol may be delisted
# No data for BEP$A
# Processing BEPC...
# Processing BEPH...
# Processing BEPI...
# Processing BEPJ...
# - BEPJ: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for BEPJ
# Processing BERY...
# Processing BEST...
# Processing BF.A...
# Got error from yahoo api for ticker BF.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BF.A: No data found for this date range, symbol may be delisted
# No data for BF.A
# Processing BF.B...
# - BF.B: No data found for this date range, symbol may be delisted
# No data for BF.B
# Processing BFAC...
# Processing BFAC.U...
# Got error from yahoo api for ticker BFAC.U, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BFAC.U: No data found for this date range, symbol may be delisted
# No data for BFAC.U
# Processing BFAC.W...
# Got error from yahoo api for ticker BFAC.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BFAC.W: No data found for this date range, symbol may be delisted
# No data for BFAC.W
# Processing BFAM...
# Processing BFH...
# Processing BFK...
# Processing BFLY...
# Processing BFLY.W...
# Got error from yahoo api for ticker BFLY.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BFLY.W: No data found for this date range, symbol may be delisted
# No data for BFLY.W
# Processing BFS...
# Processing BFS$D...
# Got error from yahoo api for ticker BFS$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BFS$D: No data found for this date range, symbol may be delisted
# No data for BFS$D
# Processing BFS$E...
# Got error from yahoo api for ticker BFS$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BFS$E: No data found for this date range, symbol may be delisted
# No data for BFS$E
# Processing BFZ...
# Processing BG...
# Processing BGB...
# Processing BGH...
# Processing BGR...
# Processing BGS...
# Processing BGSF...
# Processing BGT...
# Processing BGX...
# Processing BGY...
# Processing BH...
# Processing BH.A...
# Got error from yahoo api for ticker BH.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BH.A: No data found for this date range, symbol may be delisted
# No data for BH.A
# Processing BHC...
# Processing BHE...
# Processing BHIL...
# Processing BHK...
# Processing BHLB...
# Processing BHP...
# Processing BHR...
# Processing BHR$B...
# Got error from yahoo api for ticker BHR$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BHR$B: No data found for this date range, symbol may be delisted
# No data for BHR$B
# Processing BHR$D...
# Got error from yahoo api for ticker BHR$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BHR$D: No data found for this date range, symbol may be delisted
# No data for BHR$D
# Processing BHV...
# Processing BHVN...
# Processing BIG...
# Processing BIGZ...
# Processing BILL...
# Processing BIO...
# Processing BIO.B...
# - BIO.B: No data found for this date range, symbol may be delisted
# No data for BIO.B
# Processing BIP...
# Processing BIP$A...
# Got error from yahoo api for ticker BIP$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BIP$A: No data found for this date range, symbol may be delisted
# No data for BIP$A
# Processing BIP$B...
# Got error from yahoo api for ticker BIP$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BIP$B: No data found for this date range, symbol may be delisted
# No data for BIP$B
# Processing BIPC...
# Processing BIPH...
# Processing BIPI...
# Processing BIPJ...
# - BIPJ: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for BIPJ
# Processing BIRK...
# Processing BIT...
# Processing BJ...
# Processing BK...
# Processing BKD...
# Processing BKDT...
# Processing BKE...
# Processing BKH...
# Processing BKKT...
# Processing BKKT.W...
# Got error from yahoo api for ticker BKKT.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BKKT.W: No data found for this date range, symbol may be delisted
# No data for BKKT.W
# Processing BKN...
# Processing BKSY...
# Processing BKSY.W...
# Got error from yahoo api for ticker BKSY.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BKSY.W: No data found for this date range, symbol may be delisted
# No data for BKSY.W
# Processing BKT...
# Processing BKU...
# Processing BLCO...
# Processing BLD...
# Processing BLDR...
# Processing BLE...
# Processing BLK...
# Processing BLND...
# Processing BLW...
# Processing BLX...
# Processing BMA...
# Processing BME...
# Processing BMEZ...
# Processing BMI...
# Processing BML$G...
# Got error from yahoo api for ticker BML$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BML$G: No data found for this date range, symbol may be delisted
# No data for BML$G
# Processing BML$H...
# Got error from yahoo api for ticker BML$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BML$H: No data found for this date range, symbol may be delisted
# No data for BML$H
# Processing BML$J...
# Got error from yahoo api for ticker BML$J, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BML$J: No data found for this date range, symbol may be delisted
# No data for BML$J
# Processing BML$L...
# Got error from yahoo api for ticker BML$L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BML$L: No data found for this date range, symbol may be delisted
# No data for BML$L
# Processing BMN...
# Processing BMO...
# Processing BMY...
# Processing BN...
# Processing BNED...
# Processing BNH...
# Processing BNJ...
# Processing BNL...
# Processing BNRE...
# Processing BNRE.A...
# Got error from yahoo api for ticker BNRE.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BNRE.A: No data found for this date range, symbol may be delisted
# No data for BNRE.A
# Processing BNS...
# Processing BNY...
# Processing BOC...
# Processing BODI...
# Processing BOE...
# Processing BOH...
# Processing BOH$A...
# Got error from yahoo api for ticker BOH$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BOH$A: No data found for this date range, symbol may be delisted
# No data for BOH$A
# Processing BOH$B...
# Got error from yahoo api for ticker BOH$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BOH$B: No data found for this date range, symbol may be delisted
# No data for BOH$B
# Processing BOND...
# Processing BOOT...
# Processing BORR...
# Processing BOW...
# - BOW: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for BOW
# Processing BOWL...
# Processing BOX...
# Processing BP...
# Processing BPT...
# Processing BR...
# Processing BRBR...
# Processing BRC...
# Processing BRCC...
# Processing BRDG...
# Processing BRFS...
# Processing BRK.A...
# Got error from yahoo api for ticker BRK.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BRK.A: No data found for this date range, symbol may be delisted
# No data for BRK.A
# Processing BRK.B...
# Got error from yahoo api for ticker BRK.B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BRK.B: No data found for this date range, symbol may be delisted
# No data for BRK.B
# Processing BRO...
# Processing BROS...
# Processing BRSP...
# Processing BRT...
# Processing BRW...
# Processing BRX...
# Processing BSAC...
# Processing BSBR...
# Processing BSIG...
# Processing BSL...
# Processing BSM...
# Processing BST...
# Processing BSTZ...
# Processing BSX...
# Processing BTA...
# Processing BTCM...
# Processing BTE...
# Processing BTI...
# Processing BTO...
# Processing BTT...
# Processing BTU...
# Processing BTZ...
# Processing BUD...
# Processing BUI...
# Processing BUR...
# Processing BURL...
# Processing BUXX...
# Processing BV...
# Processing BVN...
# Processing BW...
# Processing BW$A...
# Got error from yahoo api for ticker BW$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - BW$A: No data found for this date range, symbol may be delisted
# No data for BW$A
# Processing BWA...
# Processing BWG...
# Processing BWLP...
# Processing BWMX...
# Processing BWNB...
# Processing BWSN...
# Processing BWXT...
# Processing BX...
# Processing BXC...
# Processing BXMT...
# Processing BXMX...
# Processing BXP...
# Processing BXSL...
# Processing BY...
# Processing BYD...
# Processing BYM...
# Processing BYON...
# Processing BZH...
# Processing C...
# Processing C$N...
# Got error from yahoo api for ticker C$N, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - C$N: No data found for this date range, symbol may be delisted
# No data for C$N
# Processing CAAP...
# Processing CABO...
# Processing CACI...
# Processing CADE...
# Processing CADE$A...
# Got error from yahoo api for ticker CADE$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CADE$A: No data found for this date range, symbol may be delisted
# No data for CADE$A
# Processing CAE...
# Processing CAF...
# Processing CAG...
# Processing CAH...
# Processing CAL...
# Processing CALX...
# Processing CANG...
# Processing CAPL...
# Processing CARR...
# Processing CARS...
# Processing CAT...
# Processing CATO...
# Processing CAVA...
# Processing CB...
# Processing CBH...
# Processing CBL...
# Processing CBO...
# - CBO: No data found for this date range, symbol may be delisted
# No data for CBO
# Processing CBRE...
# Processing CBT...
# Processing CBU...
# Processing CBX...
# Got error from yahoo api for ticker CBX, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CBX: No data found for this date range, symbol may be delisted
# No data for CBX
# Processing CBZ...
# Processing CC...
# Processing CCI...
# Processing CCIA...
# Processing CCIF...
# Processing CCJ...
# Processing CCK...
# Processing CCL...
# Processing CCM...
# Processing CCO...
# Processing CCRD...
# Processing CCS...
# Processing CCU...
# Processing CCZ...
# Processing CDE...
# Processing CDLR...
# Processing CDP...
# Processing CDR$B...
# Got error from yahoo api for ticker CDR$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CDR$B: No data found for this date range, symbol may be delisted
# No data for CDR$B
# Processing CDR$C...
# Got error from yahoo api for ticker CDR$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CDR$C: No data found for this date range, symbol may be delisted
# No data for CDR$C
# Processing CDRE...
# Processing CE...
# Processing CEE...
# Processing CEIX...
# Processing CELG.R...
# Got error from yahoo api for ticker CELG.R, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CELG.R: No data found for this date range, symbol may be delisted
# No data for CELG.R
# Processing CEM...
# Processing CEPU...
# Processing CF...
# Processing CFG...
# Processing CFG$E...
# Got error from yahoo api for ticker CFG$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CFG$E: No data found for this date range, symbol may be delisted
# No data for CFG$E
# Processing CFG$H...
# Got error from yahoo api for ticker CFG$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CFG$H: No data found for this date range, symbol may be delisted
# No data for CFG$H
# Processing CFR...
# Processing CFR$B...
# Got error from yahoo api for ticker CFR$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CFR$B: No data found for this date range, symbol may be delisted
# No data for CFR$B
# Processing CGA...
# Processing CGAU...
# Processing CGV...
# Processing CHCT...
# Processing CHD...
# Processing CHE...
# Processing CHGG...
# Processing CHH...
# Processing CHMI...
# Processing CHMI$A...
# Got error from yahoo api for ticker CHMI$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CHMI$A: No data found for this date range, symbol may be delisted
# No data for CHMI$A
# Processing CHMI$B...
# Got error from yahoo api for ticker CHMI$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CHMI$B: No data found for this date range, symbol may be delisted
# No data for CHMI$B
# Processing CHN...
# Processing CHPT...
# Processing CHT...
# Processing CHWY...
# Processing CI...
# Processing CIA...
# Processing CIB...
# Processing CIEN...
# Processing CIF...
# Processing CIG...
# Processing CIG.C...
# Got error from yahoo api for ticker CIG.C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIG.C: No data found for this date range, symbol may be delisted
# No data for CIG.C
# Processing CII...
# Processing CIM...
# Processing CIM$A...
# Got error from yahoo api for ticker CIM$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIM$A: No data found for this date range, symbol may be delisted
# No data for CIM$A
# Processing CIM$B...
# Got error from yahoo api for ticker CIM$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIM$B: No data found for this date range, symbol may be delisted
# No data for CIM$B
# Processing CIM$C...
# Got error from yahoo api for ticker CIM$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIM$C: No data found for this date range, symbol may be delisted
# No data for CIM$C
# Processing CIM$D...
# Got error from yahoo api for ticker CIM$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIM$D: No data found for this date range, symbol may be delisted
# No data for CIM$D
# Processing CIMN...
# - CIMN: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for CIMN
# Processing CINT...
# Processing CIO...
# Processing CIO$A...
# Got error from yahoo api for ticker CIO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CIO$A: No data found for this date range, symbol may be delisted
# No data for CIO$A
# Processing CION...
# Processing CIVI...
# Processing CL...
# Processing CLB...
# Processing CLBR...
# - CLBR: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for CLBR
# Processing CLBR.U...
# Got error from yahoo api for ticker CLBR.U, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CLBR.U: No data found for this date range, symbol may be delisted
# No data for CLBR.U
# Processing CLBR.W...
# Got error from yahoo api for ticker CLBR.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CLBR.W: No data found for this date range, symbol may be delisted
# No data for CLBR.W
# Processing CLCO...
# Processing CLDT...
# Processing CLDT$A...
# Got error from yahoo api for ticker CLDT$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CLDT$A: No data found for this date range, symbol may be delisted
# No data for CLDT$A
# Processing CLF...
# Processing CLH...
# Processing CLPR...
# Processing CLS...
# Processing CLVT...
# Processing CLW...
# Processing CLX...
# Processing CM...
# Processing CMA...
# Processing CMBT...
# Processing CMC...
# Processing CMCM...
# Processing CMG...
# Processing CMI...
# Processing CMP...
# Processing CMRE...
# Processing CMRE$B...
# Got error from yahoo api for ticker CMRE$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CMRE$B: No data found for this date range, symbol may be delisted
# No data for CMRE$B
# Processing CMRE$C...
# Got error from yahoo api for ticker CMRE$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CMRE$C: No data found for this date range, symbol may be delisted
# No data for CMRE$C
# Processing CMRE$D...
# Got error from yahoo api for ticker CMRE$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CMRE$D: No data found for this date range, symbol may be delisted
# No data for CMRE$D
# Processing CMS...
# Processing CMS$B...
# Got error from yahoo api for ticker CMS$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CMS$B: No data found for this date range, symbol may be delisted
# No data for CMS$B
# Processing CMS$C...
# Got error from yahoo api for ticker CMS$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CMS$C: No data found for this date range, symbol may be delisted
# No data for CMS$C
# Processing CMSA...
# Processing CMSC...
# Processing CMSD...
# Processing CMTG...
# Processing CMU...
# Processing CNA...
# Processing CNC...
# Processing CNF...
# Processing CNH...
# Processing CNI...
# Processing CNK...
# Processing CNM...
# Processing CNMD...
# Processing CNNE...
# Processing CNO...
# Processing CNO$A...
# Got error from yahoo api for ticker CNO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CNO$A: No data found for this date range, symbol may be delisted
# No data for CNO$A
# Processing CNP...
# Processing CNQ...
# Processing CNS...
# Processing CNX...
# Processing CODI...
# Processing CODI$A...
# Got error from yahoo api for ticker CODI$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CODI$A: No data found for this date range, symbol may be delisted
# No data for CODI$A
# Processing CODI$B...
# Got error from yahoo api for ticker CODI$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CODI$B: No data found for this date range, symbol may be delisted
# No data for CODI$B
# Processing CODI$C...
# Got error from yahoo api for ticker CODI$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CODI$C: No data found for this date range, symbol may be delisted
# No data for CODI$C
# Processing COF...
# Processing COF$I...
# Got error from yahoo api for ticker COF$I, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - COF$I: No data found for this date range, symbol may be delisted
# No data for COF$I
# Processing COF$J...
# Got error from yahoo api for ticker COF$J, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - COF$J: No data found for this date range, symbol may be delisted
# No data for COF$J
# Processing COF$K...
# Got error from yahoo api for ticker COF$K, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - COF$K: No data found for this date range, symbol may be delisted
# No data for COF$K
# Processing COF$L...
# Got error from yahoo api for ticker COF$L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - COF$L: No data found for this date range, symbol may be delisted
# No data for COF$L
# Processing COF$N...
# Got error from yahoo api for ticker COF$N, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - COF$N: No data found for this date range, symbol may be delisted
# No data for COF$N
# Processing COHR...
# Processing COLD...
# Processing COMP...
# Processing CON...
# - CON: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for CON
# Processing COOK...
# Processing COP...
# Processing COR...
# Processing COTY...
# Processing COUR...
# Processing CP...
# Processing CPA...
# Processing CPAC...
# Processing CPAY...
# Processing CPB...
# Processing CPF...
# Processing CPK...
# Processing CPNG...
# Processing CPRI...
# Processing CPS...
# Processing CPT...
# Processing CQP...
# Processing CR...
# Processing CRBG...
# Processing CRC...
# Processing CRD.A...
# Got error from yahoo api for ticker CRD.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CRD.A: No data found for this date range, symbol may be delisted
# No data for CRD.A
# Processing CRD.B...
# Got error from yahoo api for ticker CRD.B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CRD.B: No data found for this date range, symbol may be delisted
# No data for CRD.B
# Processing CRGY...
# Processing CRH...
# Processing CRI...
# Processing CRK...
# Processing CRL...
# Processing CRM...
# Processing CRS...
# Processing CRT...
# Processing CSAN...
# Processing CSL...
# Processing CSR...
# Processing CSR$C...
# Got error from yahoo api for ticker CSR$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CSR$C: No data found for this date range, symbol may be delisted
# No data for CSR$C
# Processing CSTM...
# Processing CSV...
# Processing CTA$A...
# Got error from yahoo api for ticker CTA$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTA$A: No data found for this date range, symbol may be delisted
# No data for CTA$A
# Processing CTA$B...
# Got error from yahoo api for ticker CTA$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTA$B: No data found for this date range, symbol may be delisted
# No data for CTA$B
# Processing CTBB...
# Processing CTDD...
# Processing CTEST...
# - CTEST: No data found for this date range, symbol may be delisted
# No data for CTEST
# Processing CTEST.E...
# Got error from yahoo api for ticker CTEST.E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.E: No data found for this date range, symbol may be delisted
# No data for CTEST.E
# Processing CTEST.G...
# Got error from yahoo api for ticker CTEST.G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.G: No data found for this date range, symbol may be delisted
# No data for CTEST.G
# Processing CTEST.L...
# Got error from yahoo api for ticker CTEST.L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.L: No data found for this date range, symbol may be delisted
# No data for CTEST.L
# Processing CTEST.O...
# Got error from yahoo api for ticker CTEST.O, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.O: No data found for this date range, symbol may be delisted
# No data for CTEST.O
# Processing CTEST.S...
# Got error from yahoo api for ticker CTEST.S, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.S: No data found for this date range, symbol may be delisted
# No data for CTEST.S
# Processing CTEST.V...
# Got error from yahoo api for ticker CTEST.V, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTEST.V: No data found for this date range, symbol may be delisted
# No data for CTEST.V
# Processing CTLT...
# Processing CTO...
# Processing CTO$A...
# Got error from yahoo api for ticker CTO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTO$A: No data found for this date range, symbol may be delisted
# No data for CTO$A
# Processing CTOS...
# Processing CTR...
# Processing CTRA...
# Processing CTRE...
# Processing CTRI...
# - CTRI: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for CTRI
# Processing CTS...
# Processing CTV...
# Processing CTV.W...
# Got error from yahoo api for ticker CTV.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CTV.W: No data found for this date range, symbol may be delisted
# No data for CTV.W
# Processing CTVA...
# Processing CUBB...
# Processing CUBE...
# Processing CUBI...
# Processing CUBI$E...
# Got error from yahoo api for ticker CUBI$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CUBI$E: No data found for this date range, symbol may be delisted
# No data for CUBI$E
# Processing CUBI$F...
# Got error from yahoo api for ticker CUBI$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CUBI$F: No data found for this date range, symbol may be delisted
# No data for CUBI$F
# Processing CUK...
# Processing CULP...
# Processing CURV...
# Processing CUZ...
# Processing CVE...
# Processing CVE.W...
# Got error from yahoo api for ticker CVE.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CVE.W: No data found for this date range, symbol may be delisted
# No data for CVE.W
# Processing CVEO...
# Processing CVI...
# Processing CVLG...
# Processing CVNA...
# Processing CVS...
# Processing CVX...
# Processing CW...
# Processing CWAN...
# Processing CWEN...
# Processing CWEN.A...
# Got error from yahoo api for ticker CWEN.A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - CWEN.A: No data found for this date range, symbol may be delisted
# No data for CWEN.A
# Processing CWH...
# Processing CWK...
# Processing CWT...
# Processing CX...
# Processing CXE...
# Processing CXH...
# Processing CXM...
# Processing CXT...
# Processing CXW...
# Processing CYD...
# Processing CYH...
# Processing D...
# Processing DAC...
# Processing DAL...
# Processing DAN...
# Processing DAO...
# Processing DAR...
# Processing DAVA...
# Processing DAY...
# Processing DB...
# Processing DBD...
# Processing DBI...
# Processing DBL...
# Processing DBRG...
# Processing DBRG$H...
# Got error from yahoo api for ticker DBRG$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - DBRG$H: No data found for this date range, symbol may be delisted
# No data for DBRG$H
# Processing DBRG$I...
# Got error from yahoo api for ticker DBRG$I, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - DBRG$I: No data found for this date range, symbol may be delisted
# No data for DBRG$I
# Processing DBRG$J...
# Got error from yahoo api for ticker DBRG$J, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - DBRG$J: No data found for this date range, symbol may be delisted
# ...
# - TRTN$B: No data found for this date range, symbol may be delisted
# No data for TRTN$B
# Processing TRTN$C...
# Got error from yahoo api for ticker TRTN$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TRTN$C: No data found for this date range, symbol may be delisted
# No data for TRTN$C
# Processing TRTN$D...
# Got error from yahoo api for ticker TRTN$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TRTN$D: No data found for this date range, symbol may be delisted
# No data for TRTN$D
# Processing TRTN$E...
# Got error from yahoo api for ticker TRTN$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TRTN$E: No data found for this date range, symbol may be delisted
# No data for TRTN$E
# Processing TRTX...
# Processing TRTX$C...
# Got error from yahoo api for ticker TRTX$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TRTX$C: No data found for this date range, symbol may be delisted
# No data for TRTX$C
# Processing TRU...
# Processing TRV...
# Processing TS...
# Processing TSE...
# Processing TSI...
# Processing TSLX...
# Processing TSM...
# Processing TSN...
# Processing TSQ...
# Processing TT...
# Processing TTC...
# Processing TTE...
# Processing TTI...
# Processing TTP...
# Processing TU...
# Processing TUP...
# Processing TUYA...
# Processing TV...
# Processing TVC...
# Processing TVE...
# Processing TWI...
# Processing TWLO...
# Processing TWN...
# Processing TWO...
# Processing TWO$A...
# Got error from yahoo api for ticker TWO$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TWO$A: No data found for this date range, symbol may be delisted
# No data for TWO$A
# Processing TWO$B...
# Got error from yahoo api for ticker TWO$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TWO$B: No data found for this date range, symbol may be delisted
# No data for TWO$B
# Processing TWO$C...
# Got error from yahoo api for ticker TWO$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TWO$C: No data found for this date range, symbol may be delisted
# No data for TWO$C
# Processing TX...
# Processing TXNM...
# Processing TXO...
# Processing TXT...
# Processing TY...
# Processing TY$...
# Got error from yahoo api for ticker TY$, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - TY$: No data found for this date range, symbol may be delisted
# No data for TY$
# Processing TYG...
# Processing TYL...
# Processing U...
# Processing UA...
# Processing UAA...
# Processing UAN...
# Processing UBER...
# Processing UBS...
# Processing UCB...
# Processing UCB$I...
# Got error from yahoo api for ticker UCB$I, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - UCB$I: No data found for this date range, symbol may be delisted
# No data for UCB$I
# Processing UDR...
# Processing UE...
# Processing UFI...
# Processing UGI...
# Processing UGP...
# Processing UHAL...
# Processing UHAL.B...
# - UHAL.B: No data found for this date range, symbol may be delisted
# No data for UHAL.B
# Processing UHS...
# Processing UHT...
# Processing UI...
# Processing UIS...
# Processing UL...
# Processing ULS...
# - ULS: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for ULS
# Processing UMC...
# Processing UMH...
# Processing UMH$D...
# Got error from yahoo api for ticker UMH$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - UMH$D: No data found for this date range, symbol may be delisted
# No data for UMH$D
# Processing UNF...
# Processing UNFI...
# Processing UNH...
# Processing UNM...
# Processing UNMA...
# Processing UNP...
# Processing UP...
# Processing UPS...
# Processing URI...
# Processing USA...
# Processing USAC...
# Processing USB...
# Processing USB$A...
# Got error from yahoo api for ticker USB$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$A: No data found for this date range, symbol may be delisted
# No data for USB$A
# Processing USB$H...
# Got error from yahoo api for ticker USB$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$H: No data found for this date range, symbol may be delisted
# No data for USB$H
# Processing USB$P...
# Got error from yahoo api for ticker USB$P, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$P: No data found for this date range, symbol may be delisted
# No data for USB$P
# Processing USB$Q...
# Got error from yahoo api for ticker USB$Q, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$Q: No data found for this date range, symbol may be delisted
# No data for USB$Q
# Processing USB$R...
# Got error from yahoo api for ticker USB$R, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$R: No data found for this date range, symbol may be delisted
# No data for USB$R
# Processing USB$S...
# Got error from yahoo api for ticker USB$S, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - USB$S: No data found for this date range, symbol may be delisted
# No data for USB$S
# Processing USFD...
# Processing USM...
# Processing USNA...
# Processing USPH...
# Processing UTF...
# Processing UTI...
# Processing UTL...
# Processing UTZ...
# Processing UVE...
# Processing UVV...
# Processing UWMC...
# Processing UWMC.W...
# Got error from yahoo api for ticker UWMC.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - UWMC.W: No data found for this date range, symbol may be delisted
# No data for UWMC.W
# Processing UZD...
# Processing UZE...
# Processing UZF...
# Processing V...
# Processing VAC...
# Processing VAL...
# Processing VAL.W...
# Got error from yahoo api for ticker VAL.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VAL.W: No data found for this date range, symbol may be delisted
# No data for VAL.W
# Processing VALE...
# Processing VATE...
# Processing VBF...
# Processing VCV...
# Processing VEEV...
# Processing VEL...
# Processing VET...
# Processing VFC...
# Processing VGI...
# Processing VGM...
# Processing VGR...
# Processing VHC...
# Processing VHI...
# Processing VICI...
# Processing VIK...
# - VIK: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for VIK
# Processing VIPS...
# Processing VIST...
# Processing VIV...
# Processing VKQ...
# Processing VLD...
# Processing VLD.W...
# Got error from yahoo api for ticker VLD.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VLD.W: No data found for this date range, symbol may be delisted
# No data for VLD.W
# Processing VLN...
# Processing VLN.W...
# Got error from yahoo api for ticker VLN.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VLN.W: No data found for this date range, symbol may be delisted
# No data for VLN.W
# Processing VLO...
# Processing VLRS...
# Processing VLT...
# Processing VLTO...
# Processing VMC...
# Processing VMI...
# Processing VMO...
# Processing VNCE...
# Processing VNO...
# Processing VNO$L...
# Got error from yahoo api for ticker VNO$L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VNO$L: No data found for this date range, symbol may be delisted
# No data for VNO$L
# Processing VNO$M...
# Got error from yahoo api for ticker VNO$M, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VNO$M: No data found for this date range, symbol may be delisted
# No data for VNO$M
# Processing VNO$N...
# Got error from yahoo api for ticker VNO$N, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VNO$N: No data found for this date range, symbol may be delisted
# No data for VNO$N
# Processing VNO$O...
# Got error from yahoo api for ticker VNO$O, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VNO$O: No data found for this date range, symbol may be delisted
# No data for VNO$O
# Processing VNT...
# Processing VOC...
# Processing VOTE...
# Processing VOYA...
# Processing VOYA$B...
# Got error from yahoo api for ticker VOYA$B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - VOYA$B: No data found for this date range, symbol may be delisted
# No data for VOYA$B
# Processing VPG...
# Processing VPV...
# Processing VRE...
# Processing VRN...
# Processing VRT...
# Processing VRTS...
# Processing VSCO...
# Processing VSH...
# Processing VST...
# Processing VSTO...
# Processing VSTS...
# Processing VTEX...
# Processing VTLE...
# Processing VTMX...
# Processing VTN...
# Processing VTOL...
# Processing VTR...
# Processing VTS...
# Processing VVI...
# Processing VVR...
# Processing VVV...
# Processing VVX...
# Processing VYX...
# Processing VZ...
# Processing VZIO...
# Processing W...
# Processing WAB...
# Processing WAL...
# Processing WAL$A...
# Got error from yahoo api for ticker WAL$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WAL$A: No data found for this date range, symbol may be delisted
# No data for WAL$A
# Processing WAT...
# Processing WBS...
# Processing WBS$F...
# Got error from yahoo api for ticker WBS$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WBS$F: No data found for this date range, symbol may be delisted
# No data for WBS$F
# Processing WBS$G...
# Got error from yahoo api for ticker WBS$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WBS$G: No data found for this date range, symbol may be delisted
# No data for WBS$G
# Processing WBX...
# Processing WBX.W...
# Got error from yahoo api for ticker WBX.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WBX.W: No data found for this date range, symbol may be delisted
# No data for WBX.W
# Processing WCC...
# Processing WCC$A...
# Got error from yahoo api for ticker WCC$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WCC$A: No data found for this date range, symbol may be delisted
# No data for WCC$A
# Processing WCN...
# Processing WD...
# Processing WDH...
# Processing WDI...
# Processing WDS...
# Processing WEA...
# Processing WEAV...
# Processing WEC...
# Processing WEL...
# Processing WEL.U...
# Got error from yahoo api for ticker WEL.U, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WEL.U: No data found for this date range, symbol may be delisted
# No data for WEL.U
# Processing WEL.W...
# Got error from yahoo api for ticker WEL.W, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WEL.W: No data found for this date range, symbol may be delisted
# No data for WEL.W
# Processing WELL...
# Processing WES...
# Processing WEX...
# Processing WF...
# Processing WFC...
# Processing WFC$A...
# Got error from yahoo api for ticker WFC$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$A: No data found for this date range, symbol may be delisted
# No data for WFC$A
# Processing WFC$C...
# Got error from yahoo api for ticker WFC$C, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$C: No data found for this date range, symbol may be delisted
# No data for WFC$C
# Processing WFC$D...
# Got error from yahoo api for ticker WFC$D, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$D: No data found for this date range, symbol may be delisted
# No data for WFC$D
# Processing WFC$L...
# Got error from yahoo api for ticker WFC$L, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$L: No data found for this date range, symbol may be delisted
# No data for WFC$L
# Processing WFC$Y...
# Got error from yahoo api for ticker WFC$Y, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$Y: No data found for this date range, symbol may be delisted
# No data for WFC$Y
# Processing WFC$Z...
# Got error from yahoo api for ticker WFC$Z, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WFC$Z: No data found for this date range, symbol may be delisted
# No data for WFC$Z
# Processing WFG...
# Processing WGO...
# Processing WH...
# Processing WHD...
# Processing WHG...
# Processing WHR...
# Processing WIA...
# Processing WINN...
# Processing WIT...
# Processing WIW...
# Processing WK...
# Processing WKC...
# Processing WLK...
# Processing WLKP...
# Processing WLY...
# Processing WLYB...
# Processing WM...
# Processing WMB...
# Processing WMK...
# Processing WMS...
# Processing WMT...
# Processing WNC...
# Processing WNS...
# Processing WOLF...
# Processing WOR...
# Processing WOW...
# Processing WPC...
# Processing WPM...
# Processing WPP...
# Processing WRB...
# Processing WRB$E...
# Got error from yahoo api for ticker WRB$E, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WRB$E: No data found for this date range, symbol may be delisted
# No data for WRB$E
# Processing WRB$F...
# Got error from yahoo api for ticker WRB$F, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WRB$F: No data found for this date range, symbol may be delisted
# No data for WRB$F
# Processing WRB$G...
# Got error from yahoo api for ticker WRB$G, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WRB$G: No data found for this date range, symbol may be delisted
# No data for WRB$G
# Processing WRB$H...
# Got error from yahoo api for ticker WRB$H, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WRB$H: No data found for this date range, symbol may be delisted
# No data for WRB$H
# Processing WRBY...
# Processing WS...
# Processing WSM...
# Processing WSO...
# Processing WSO.B...
# Got error from yahoo api for ticker WSO.B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - WSO.B: No data found for this date range, symbol may be delisted
# No data for WSO.B
# Processing WSR...
# Processing WST...
# Processing WT...
# Processing WTI...
# Processing WTM...
# Processing WTRG...
# Processing WTS...
# Processing WTTR...
# Processing WU...
# Processing WWW...
# Processing WY...
# Processing X...
# Processing XFLT...
# Processing XFLT$A...
# Got error from yahoo api for ticker XFLT$A, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - XFLT$A: No data found for this date range, symbol may be delisted
# No data for XFLT$A
# Processing XHR...
# Processing XIN...
# Processing XOM...
# Processing XPER...
# Processing XPEV...
# Processing XPO...
# Processing XPOF...
# Processing XPRO...
# Processing XYF...
# Processing XYL...
# Processing YALA...
# Processing YELP...
# Processing YETI...
# Processing YEXT...
# Processing YMM...
# Processing YOU...
# Processing YPF...
# Processing YRD...
# Processing YSG...
# Processing YUM...
# Processing YUMC...
# Processing ZBH...
# Processing ZEPP...
# Processing ZETA...
# Processing ZGN...
# Processing ZH...
# Processing ZIM...
# Processing ZIP...
# Processing ZK...
# - ZK: Data doesn't exist for startDate = 1672549200, endDate = 1703998800
# No data for ZK
# Processing ZKH...
# Processing ZTO...
# Processing ZTR...
# Processing ZTS...
# Processing ZUO...
# Processing ZVIA...
# Processing ZWS...
#      Ticker  Mean Return (Annualized)  Risk (Annualized Std Dev)
# 0         A                 -0.034023                   0.268363
# 1        AA                 -0.127481                   0.521057
# 2      AACT                  0.058869                   0.020514
# 3       AAN                  0.147949                   0.613875
# 4       AAP                 -0.745538                   0.516189
# ...     ...                       ...                        ...
# 2385    ZTR                 -0.034899                   0.164218
# 2386    ZTS                  0.339549                   0.250276
# 2387    ZUO                  0.498369                   0.507373
# 2388   ZVIA                 -0.484177                   0.698478
# 2389    ZWS                  0.379987                   0.292649
#
# [2390 rows x 3 columns]
